# %% [markdown]
# # Machine Learning Basics
# In this module, you'll be analysing a dataset. You will be using the Cinema Data for the tasks in this module. <br> <br>
# **Pipeline:**
# * Acquiring the data - done
# * Handling files and formats - done
# * Data Analysis
# * Prediction
# * Analysing results

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1 - Plotting
# * Plot the values of occupancy percentage versus number of weeks since release, for all movies in the dataset.
# * Plot the number of other releases in the week versus occupancy percentage and weeks until the end of lifetime, for all movies.
# * Plot the number of shows in the week versus occupancy percentage and weeks until the end of lifetime, for all movies.

# %%
def first_plot():
    file=open("CinemaData.csv",'r')
    global df
    df=pd.read_csv("CinemaData.csv")
    x=df.OccPer
    y=df.WeeksSinceRelease
    plott=plt.scatter(x,y)
    plt.title(" Occupancy percentage Vs Number of weeks since release")
    return plott

# %%
first_plot()

# %%
"""Plot the number of other releases in the week versus occupancy 
percentage and weeks until the end of lifetime, for all movies."""


def one():
    y1=df.OtherReleasesInWeek
    x=df.OccPer
    y2=df.Lifetime
    
    str1="OtherReleasesInWeek vs OccPer"
    str2="OtherReleasesInWeek vs Lifetime"
    
    plot1 = plt.figure(1)
    plt.scatter(x,y1,color="blue")
    plt.title(str1)
    
    
    plot2 = plt.figure(2)
    plot2=plt.scatter(y1,y2,color="black")
    plt.title(str2)
   
    return plot1,plot2

# %%
one()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.collections.PathCollection at 0x18bd6d79fd0>)

# %%
"""Plot the number of shows in the week versus occupancy 
percentage and weeks until the end of lifetime, for all movie"""
def second():
    y1=df.ShowsInWeek
    x1=df.OccPer
    y2=df.Lifetime
    str1="ShowsInWeek vs OccPer"
    str2="ShowsInWeek vs Lifetime"
     
    plot1 = plt.figure(1)
    plt.scatter(x1,y1,color="blue")
    plt.title(str1)
    
    
    plot2 = plt.figure(2)
    plot2=plt.scatter(y2,y1,color="black")
    plt.title(str2)
   
    return plot1,plot2

# %%
second()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.collections.PathCollection at 0x18bd7fe3d60>)

# %% [markdown]
# ## Task 2 - Reasoning
# Now that you have the plots, identify the correlation between the various parameters analysed. Justify the correlations, your observations, and your hypotheses for the same with appropriate reasoning.

# %%
Plot 1-( occupancy percentage versus number of weeks since release)
In this plot it can be observed that the occupancy percentage for most of the movies hits its peak  at the day of release and 
gradually decreases as the days and weeks pass. But, it is seen in some movies that it hits peak occupancy percentage at the 
first , second or third week from release.
The average weeks run for each movie is about 2 weeks from release, while the minimum weeks run by a movie is '0' and the maximum weeks 
from release for a movie is '148'.
It is also observed that some movies have run 20-40 weeks from release.
The highest occupancy percentage for a movie is observed to be '1.0' and the lowest occupancy percentage for a movie is observed to be '0.0181' 
and the average being '0.733'


Plot 2-'Number of other releases in the week versus Occupancy percentage'
In this Plot it can be observed that the occupancy percentage ranges between '0.181' to '1'. It can be observed that the minimum(0.181) occupancy occurs 
when there are eleven movies realeasing in that week while the maximum(1) occurs at five movies releasing in that week.It can also be observed that the occupancy
percentage increases as the number of other releases increases.The number of other releases in the week ranges between '1' and '16'.

Plot- 3-'Other releases in week versus Lifetime'
In this Plot it can be observed that the Lifetime ranges between '0' and the highest being '148'.The number of other releases in the week ranges between 
'1' and '16'.It can be clearly observed that only one Lifetime of a movie exceeds '40' and all the other lifetimes fall under '40'. It can also be seen that 
70% of the films lifetime falls under '20'.

Plot- 4-'ShowsinWeek versus OCCper'
In this Plot it can be observed that the occupancy percentage ranges between '0.181' to '1'.The number of shows in week ranges between '1' and '192'.
It can be seen that most of occupancy percentage lies between '1' to '50' shows in week.It can also be seen that the values thin out after '50' and become less
in frequency.

Plot- 5-'ShowinWeek vs Lifetime'
The number of shows in week ranges between '1' and '192'.And the Lifetime ranges between '0' and the highest being '148'.It can be clearly observed that 95%
of the values lie between '0' and '40' and only few value exceed '40' out of which '148' being the highest.It can also be seen that the frequency of the shows
in week lies between '0' to '60' and the frequency lowers as we go above 60.
# Out:
#   File "<ipython-input-9-9ffd95b9a83c>", line 1
#     Plot 1-( occupancy percentage versus number of weeks since release)
#          ^
# SyntaxError: invalid syntax
